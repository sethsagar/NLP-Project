# %%
import pandas as pd

# %%
data_path = 'data/QQP/paws_qqp/output/'
train_data = pd.read_table(data_path+'train.tsv',header=0)
test_data = pd.read_table(data_path+'dev_and_test.tsv',header=0)

# %%
train_data
# Out:
#           id                                          sentence1  \
# 0          1  b'Will a message still say blocked if you were...
# 1          2  b'How can you treat ocd ? Is there any helpful...
# 2          3  b'If you do not do anything how you are motiva...
# 3          4  b'Why is new in system verily constructor not ...
# 4          5  b'What are the most common traffic convictions...
# ...      ...                                                ...
# 11983  11984  b'Do you think Hillary Clinton had Seth Rich k...
# 11984  11985           b'How do you become attractive/pretty ?'
# 11985  11986  b"`` What do a Pakistani will tell when someon...
# 11986  11987  b'Are professional traders better at investing...
# 11987  11988  b'Why can I understand other people and unders...
#
#                                                sentence2  label
# 0      b'Will a message still say delivered if you we...      0
# 1      b'How can you treat OCD ? Is there any helpful...      1
# ...

# %%
test_data
# Out:
#       id                                          sentence1  \
# 0      1  b'What were the major effects of the cambodia ...
# 1      2  b"The guy I 'm dating never texts me and I fee...
# 2      3  b"How do I make my new phone number as group a...
# 3      4  b"Why ca n't countries afford high quality pro...
# 4      5  b'Do Mexican women like East Asian men ( Korea...
# ..   ...                                                ...
# 672  673  b'Can a native French speaker tell when talkin...
# 673  674  b"Let 's say I do n't believe the world is rou...
# 674  675  b'How is blade commerce controlled in Vermont ...
# 675  676  b'Is Gautam Buddha University taking any steps...
# 676  677  b"Can I do get a master 's in mechanical engin...
#
#                                              sentence2  label
# 0    b'What were the major effects of the Iquique e...      0
# 1    b"The guy I 'm dating never wants me and I fee...      0
# ...
